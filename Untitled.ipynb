# %%
import pandas as pd
# anexo_tres_virtual = pd.read_excel('priori/Anexo III rev2.xlsx')
# anexo_tres = pd.read_excel('priori/Anexo III rev1.xlsx')
# anexo_quatro = pd.read_excel('priori/Anexo IV rev1.xlsx')
# anexo_cinco = pd.read_excel('priori/Anexo V.xlsx')
# anexo_vir = pd.read_excel('priori/Virtuais.xlsx')
# anexo_seis = pd.read_excel('priori/Anexo VI rev1.xlsx')
anexo_seis.to_clipboard()
display(anexo_seis)
# Out:
#           id  numero  num novo   Ativo  \
# 0     600003     NaN    600003  600003
# 1     600080     NaN    600080  600080
# 2     600517     NaN    600517  600517
# 3     600452     NaN    600452  600452
# 4     603281     NaN    603281  603281
# ...      ...     ...       ...     ...
# 1729  606180     NaN    606180  606180
# 1730  606184     NaN    606184  606184
# 1731  606185     NaN    606185  606185
# 1732  603560     NaN    603560  603560
# 1733  603569     NaN    603569  603569
#
#                                               Descricao    Estado do bem  \
# 0     GAVETEIRO COM 4 GAVETA COMPRIMENTO 0,60 LARGUR...  REGULAR/ EM USO
# 1     GAVETEIRO volante p/ composição de estação de ...  REGULAR/ EM USO
# 2                                    MONITOR LCD HP 23"  REGULAR/ EM USO
# 3                        03/00226 - BLOCO PADRAO EM ACO  REGULAR/ EM USO
# 4                                  MONITOR LCD\nINFOWAY  REGULAR/ EM USO
# ...
